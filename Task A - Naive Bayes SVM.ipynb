# %%
import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sb

import os
import nltk
from nltk.corpus import stopwords
import seaborn as sns
from sklearn.metrics import f1_score
from sklearn.model_selection import KFold
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB,MultinomialNB,ComplementNB,BernoulliNB

import re
import emoji

from collections import Counter
from sklearn.datasets import make_classification

from imblearn.under_sampling import RandomUnderSampler
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix

from nltk import FreqDist
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

# !pip install emoji
# Out:
# Using TensorFlow backend.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/nikhiloswal/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/nikhiloswal/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Reading dataset

# %%
train_data = pd.read_csv('./datasets/training-v1/offenseval-training-v1.tsv' , sep='\t')

# %% [markdown]
# ## Exploratory Data Analysis

# %%
train_data
# Out:
#           id                                              tweet subtask_a  \
# 0      86426  @USER She should ask a few native Americans wh...       OFF
# 1      90194  @USER @USER Go home you’re drunk!!! @USER #MAG...       OFF
# 2      16820  Amazon is investigating Chinese employees who ...       NOT
# 3      62688  @USER Someone should'veTaken" this piece of sh...       OFF
# 4      43605  @USER @USER Obama wanted liberals &amp; illega...       NOT
# 5      97670                  @USER Liberals are all Kookoo !!!       OFF
# 6      77444                   @USER @USER Oh noes! Tough shit.       OFF
# 7      52415  @USER was literally just talking about this lo...       OFF
# 8      45157                         @USER Buy more icecream!!!       NOT
# 9      13384  @USER Canada doesn’t need another CUCK! We alr...       OFF
# 10     82776  @USER @USER @USER It’s not my fault you suppor...       NOT
# 11     42992  @USER What’s the difference between #Kavanaugh...       NOT
# 12     28414  @USER you are a lying corrupt traitor!!! Nobod...       OFF
# 13     54920  @USER @USER @USER It should scare every Americ...       NOT
# 14     56392  @USER @USER @USER @USER @USER @USER @USER @USE...       NOT
# 15     86735               @USER you are also the king of taste       NOT
# 16     95686  #MAGA @USER  🎶 Sing like no one is listening  ...       NOT
# 17     71446  5/5: @USER The time is right for this House to...       NOT
# 18     23958  @USER Besides Jax’s mom and maybe Ope he is ha...       NOT
# 19     28195  @USER @USER @USER gun control! That is all the...       OFF
# 20     56117  @USER @USER @USER @USER LOL!!!   Throwing the ...       OFF
# 21     67757                       @USER @USER You are correct.       NOT
# 22     12681  @USER @USER Kind of like when conservatives wa...       OFF
# 23     82904  @USER @USER Da fuck is going on people?   Ther...       OFF
# 24     63236  @USER Been a Willie fan since before most of y...       NOT
# 25     77665  @USER Tbh these days i just don't like people ...       OFF
# 26     83484  South Korean Official: “Leaders will discuss s...       NOT
# 27     74932        @USER @USER You can tell he is a hooper too       NOT
# 28     91252   @USER I feel like he is better chasing the title       NOT
# 29     25440  @USER @USER @USER She?  To whom are you referr...       OFF
# ...      ...                                                ...       ...
# 13210  73518                @USER He is 😭😭😭 he is so precious 💖       NOT
# 13211  51204                                    @USER Booooring       NOT
# 13212  93164  @USER @USER Everything else was ten years ago....       OFF
# 13213  98218  @USER @USER @USER @USER Right. Dang. She is th...       NOT
# 13214  94976  @USER @USER McRaven engaged in a publicity stu...       NOT
# 13215  55677  @USER @USER Oh man! You are going to trigger t...       NOT
# 13216  17250  @USER Aw Chelsea it never ends. You are as alw...       NOT
# 13217  61083                    @USER “My head is a fuckin egg”       OFF
# 13218  39742  @USER @USER @USER @USER @USER @USER @USER @USE...       NOT
# 13219  72262  @USER @USER Did you serve?   You rate at botto...       NOT
# 13220  28996  .@USER is right to say that housing associatio...       NOT
# 13221  20121  @USER @USER is just trying to make good with h...       NOT
# 13222  64713  @USER @USER I'm a Boise State fan so I can tel...       NOT
# 13223  63482  @USER is advocating for conduct within bounds ...       OFF
# 13224  33567  @USER @USER @USER So have the conservatives ac...       NOT
# 13225  22965  @USER Can we all agree that Tomlins seat is he...       NOT
# 13226  11132                     @USER when you coming to ohio?       NOT
# 13227  87416  @USER @USER @USER @USER Liars like the Antifa ...       OFF
# 13228  56034  @USER @USER He is involved because he was ther...       NOT
# 13229  34461  @USER @USER @USER How much lonely she is and h...       NOT
# 13230  90041  @USER @USER Billy you have a short memory. Oba...       NOT
# 13231  93038                     @USER @USER BUT GUN CONTROL!!!       NOT
# 13232  98824  @USER She is not the brightest light on the tree.       NOT
# 13233  99696  @USER 😂😂😂😂😂😂 if I say you are mad now you will...       NOT
# 13234  17500  @USER @USER @USER @USER @USER @USER @USER @USE...       NOT
# 13235  95338  @USER Sometimes I get strong vibes from people...       OFF
# 13236  67210  Benidorm ✅  Creamfields ✅  Maga ✅   Not too sh...       NOT
# 13237  82921  @USER And why report this garbage.  We don't g...       OFF
# 13238  27429                                        @USER Pussy       OFF
# 13239  46552  #Spanishrevenge vs. #justice #HumanRights and ...       NOT
#
#       subtask_b subtask_c
# 0           UNT       NaN
# 1           TIN       IND
# 2           NaN       NaN
# 3           UNT       NaN
# 4           NaN       NaN
# 5           TIN       OTH
# 6           UNT       NaN
# 7           TIN       GRP
# 8           NaN       NaN
# 9           TIN       IND
# 10          NaN       NaN
# 11          NaN       NaN
# 12          TIN       IND
# 13          NaN       NaN
# 14          NaN       NaN
# 15          NaN       NaN
# 16          NaN       NaN
# 17          NaN       NaN
# 18          NaN       NaN
# 19          TIN       OTH
# 20          TIN       IND
# 21          NaN       NaN
# 22          TIN       GRP
# 23          TIN       GRP
# 24          NaN       NaN
# 25          TIN       IND
# 26          NaN       NaN
# 27          NaN       NaN
# 28          NaN       NaN
# 29          UNT       NaN
# ...         ...       ...
# 13210       NaN       NaN
# 13211       NaN       NaN
# 13212       TIN       IND
# 13213       NaN       NaN
# 13214       NaN       NaN
# 13215       NaN       NaN
# 13216       NaN       NaN
# 13217       UNT       NaN
# 13218       NaN       NaN
# 13219       NaN       NaN
# 13220       NaN       NaN
# 13221       NaN       NaN
# 13222       NaN       NaN
# 13223       TIN       GRP
# 13224       NaN       NaN
# 13225       NaN       NaN
# 13226       NaN       NaN
# 13227       TIN       GRP
# 13228       NaN       NaN
# 13229       NaN       NaN
# 13230       NaN       NaN
# 13231       NaN       NaN
# 13232       NaN       NaN
# 13233       NaN       NaN
# 13234       NaN       NaN
# 13235       TIN       IND
# 13236       NaN       NaN
# 13237       TIN       OTH
# 13238       UNT       NaN
# 13239       NaN       NaN
#
# [13240 rows x 5 columns]

# %%
array = ['GRP', 'IND']
train_data.loc[train_data['subtask_c'].isin(array)]
# Out:
#           id                                              tweet subtask_a  \
# 1      90194  @USER @USER Go home you’re drunk!!! @USER #MAG...       OFF
# 7      52415  @USER was literally just talking about this lo...       OFF
# 9      13384  @USER Canada doesn’t need another CUCK! We alr...       OFF
# 12     28414  @USER you are a lying corrupt traitor!!! Nobod...       OFF
# 20     56117  @USER @USER @USER @USER LOL!!!   Throwing the ...       OFF
# 22     12681  @USER @USER Kind of like when conservatives wa...       OFF
# 23     82904  @USER @USER Da fuck is going on people?   Ther...       OFF
# 25     77665  @USER Tbh these days i just don't like people ...       OFF
# 32     12609  The only thing the Democrats have is lying and...       OFF
# 36     12108  @USER @USER @USER @USER @USER @USER @USER @USE...       OFF
# 37     14726  @USER @USER @USER That's expected if you placa...       OFF
# 54     84102  4 out of 10 British people are basically full-...       OFF
# 57     98992                                     @USER Fuck off       OFF
# 60     75215  @USER @USER She is useless.  Attempts to do th...       OFF
# 62     57013  @USER Grateful Trump doesn’t have a dog in the...       OFF
# 64     74831           @USER Trump kicks dem butt - its so fun.       OFF
# 65     53264  @USER @USER @USER He is dumb and dumber all in...       OFF
# 68     84664  @USER And this from the clown that should be i...       OFF
# 70     48995            @USER Thats because you are an old man.       OFF
# 74     64429  @USER I mean it worked for gun control right? URL       OFF
# 83     45068  @USER She is drinking so much koolaid she’s bl...       OFF
# 86     84667  @USER @USER @USER @USER The Institution only l...       OFF
# 89     93119  WTC This is a threat!!! ..@USER #Maga #QAnon #...       OFF
# 94     21379  @USER @USER @USER Please call trump out for wh...       OFF
# 106    52252                                      @USER Fuck em       OFF
# 107    91001             @USER Good move....he is the big loser       OFF
# 112    80561  @USER @USER There are many dumb arguments for ...       OFF
# 120    39907  @USER @USER @USER please don't kill me. antifa...       OFF
# 123    77294  @USER @USER She is an ugly black hearted troll...       OFF
# 129    28841     @USER @USER We have been saved from you! MAGA!       OFF
# ...      ...                                                ...       ...
# 13112  11924  @USER @USER @USER @USER First have a very old ...       OFF
# 13114  30186          @USER @USER @USER I think he is on crack!       OFF
# 13115  48232  @USER OH I FUCKING LOVE LATEX HMU IFU GOT Q'S ...       OFF
# 13126  32824  @USER She makes me sick.  She uses these confi...       OFF
# 13127  11628  @USER @USER @USER Trump wanted to be president...       OFF
# 13131  83202                          @USER @USER He is a pedo.       OFF
# 13136  14655  @USER @USER @USER He is embarrassing and just ...       OFF
# 13151  77459  @USER It’s just people who say they hate ident...       OFF
# 13153  88200  @USER Bullshit! People died because of an inco...       OFF
# 13154  33624  @USER She is a repulsive human in every possib...       OFF
# 13159  28037  Thinking about the Student-Loan Crisis"  URL #...       OFF
# 13162  79156  @USER @USER Why would they drag their feet? If...       OFF
# 13163  84367  @USER @USER No I have no relationship with him...       OFF
# 13166  84499  @USER Agree. That’s hatred beyond compare. Her...       OFF
# 13169  50151  @USER All we ever hear from Hillary is beechin...       OFF
# 13171  19742  @USER @USER Simply to get the smear campaign g...       OFF
# 13173  36225      @USER Go to Iran where u belong stupid idiot.       OFF
# 13178  59918  @USER @USER @USER @USER @USER She raps likes s...       OFF
# 13179  37666  @USER @USER @USER @USER You should know better...       OFF
# 13180  16225  @USER Got a feeling every time deep state comp...       OFF
# 13182  50445  @USER this jag off ref Tony Corrente needs to ...       OFF
# 13184  83365  @USER @USER You can't be this dense. The point...       OFF
# 13185  28748  @USER Google CFO is a joke! And so is the idio...       OFF
# 13187  85250   @USER she is human garbage that is what is wrong       OFF
# 13195  37397          @USER nah it's coz you're a cunt. blocked       OFF
# 13207  86716  @USER Omg not even interested in his age but d...       OFF
# 13212  93164  @USER @USER Everything else was ten years ago....       OFF
# 13223  63482  @USER is advocating for conduct within bounds ...       OFF
# 13227  87416  @USER @USER @USER @USER Liars like the Antifa ...       OFF
# 13235  95338  @USER Sometimes I get strong vibes from people...       OFF
#
#       subtask_b subtask_c
# 1           TIN       IND
# 7           TIN       GRP
# 9           TIN       IND
# 12          TIN       IND
# 20          TIN       IND
# 22          TIN       GRP
# 23          TIN       GRP
# 25          TIN       IND
# 32          TIN       GRP
# 36          TIN       IND
# 37          TIN       GRP
# 54          TIN       GRP
# 57          TIN       IND
# 60          TIN       IND
# 62          TIN       IND
# 64          TIN       IND
# 65          TIN       IND
# 68          TIN       IND
# 70          TIN       IND
# 74          TIN       GRP
# 83          TIN       IND
# 86          TIN       IND
# 89          TIN       IND
# 94          TIN       IND
# 106         TIN       GRP
# 107         TIN       IND
# 112         TIN       IND
# 120         TIN       IND
# 123         TIN       IND
# 129         TIN       IND
# ...         ...       ...
# 13112       TIN       IND
# 13114       TIN       IND
# 13115       TIN       IND
# 13126       TIN       IND
# 13127       TIN       IND
# 13131       TIN       IND
# 13136       TIN       IND
# 13151       TIN       GRP
# 13153       TIN       IND
# 13154       TIN       IND
# 13159       TIN       IND
# 13162       TIN       GRP
# 13163       TIN       IND
# 13166       TIN       IND
# 13169       TIN       IND
# 13171       TIN       IND
# 13173       TIN       IND
# 13178       TIN       IND
# 13179       TIN       GRP
# 13180       TIN       IND
# 13182       TIN       IND
# 13184       TIN       GRP
# 13185       TIN       IND
# 13187       TIN       IND
# 13195       TIN       IND
# 13207       TIN       IND
# 13212       TIN       IND
# 13223       TIN       GRP
# 13227       TIN       GRP
# 13235       TIN       IND
#
# [3481 rows x 5 columns]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13240 entries, 0 to 13239
# Data columns (total 5 columns):
# id           13240 non-null int64
# tweet        13240 non-null object
# subtask_a    13240 non-null object
# subtask_b    4400 non-null object
# subtask_c    3876 non-null object
# dtypes: int64(1), object(4)
# memory usage: 517.3+ KB

# %%
ax=train_data['subtask_a'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%' ,shadow=True)
ax.set_title('Distribution of Question')
ax.set_ylabel('')
plt.show()

# %%
plot_sb = sb.countplot(train_data['subtask_a'], label='Total')
NOT, OFF  = train_data['subtask_a'].value_counts()
print('Offensive: ',OFF)
print('Not Offensive : ',NOT)
# Out:
# Offensive:  4400
# Not Offensive :  8840

# %% [markdown]
# ## Preprocessing Dataset

# %%
def handle_emoji(text):
    # Dictionnary of "important" emojis : 
    emoji_dict =  {'♥️': ' love ',
                   '❤️' : ' love ',
                   '❤' : ' love ',
                   '😘' : ' kisses ',
                  '😭' : ' cry ',
                  '💪' : ' strong ',
                  '🌍' : ' earth ',
                  '💰' : ' money ',
                  '👍' : ' ok ',
                   '👌' : ' ok ',
                  '😡' : ' angry ',
                  '🍆' : ' dick ',
                  '🤣' : ' haha ',
                  '😂' : ' haha ',
                  '🖕' : ' fuck you '}

    for cha in emoji_dict:
        text = re.compile(str(cha)).sub(str(emoji_dict[cha]),text)
    # Remove ALL emojis
    text = emoji.get_emoji_regexp().sub(r' ',text) 
    text = re.compile("([\U0001f3fb-\U0001f3ff])").sub(r'',text) 
    text = re.compile("([\U00010000-\U0010ffff])").sub(r'',text) 
    text = re.compile("(\u00a9|\u00ae|[\u2000-\u3300]|\ud83c[\ud000-\udfff]|\ud83d[\ud000-\udfff]|\ud83e[\ud000-\udfff])").sub(r'',text)

    # Add Space between  the Emoji Expressions : 
    text = re.compile("([\U00010000-\U0010ffff])").sub(r' \1 ',text) 
    return text

# %%
def clean_tweet(text):
    ''' Function that is applied to every to tweet in the dataset '''

    # =========== TEXT ===========
    # Replace @USER by <user>
    text = re.compile(r'@USER').sub(r'<user>',text)

    # Replace URL by <url>
    text = re.compile(r'URL').sub(r'<url>',text)

    # Remove numbers :
    text = re.compile(r'[0-9]+').sub(r' ',text)

    # Remove some special characters
    text = re.compile(r'([\xa0_\{\}\[\]¬•$,:;/@#|\^*%().~`”"“-])').sub(r' ',text) 

    # Space the special characters with white spaces
    text = re.compile(r'([$&+,:;=?@#|\'.^*()%!"’“-])').sub(r' \1 ',text)

    # Replace some special characters : 
    replace_dict = {r'&' : 'and' , r'&amp;' : 'and' , 
                    r'\+' : 'plus'}
    for cha in replace_dict:
        text = re.compile(str(cha)).sub(str(replace_dict[cha]),text)

    # Handle Emoji : translate some and delete the others
    text = handle_emoji(text)

    # Word delengthening : 
    text = re.compile(r'(.)\1{3,}').sub(r'\1\1',text)

    # Cut the words with caps in them : 
    text = re.compile(r'([a-z]+|[A-Z]+|[A-Z][a-z]+)([A-Z][a-z]+)').sub(r'\1 \2',text)
    text = re.compile(r'([a-z]+|[A-Z]+|[A-Z][a-z]+)([A-Z][a-z]+)').sub(r'\1 \2',text)        
    # =========== TOKENS ===========
    # TOKENIZE 
    text = text.split(' ')

    # Remove white spaces tokens
    text = [text[i] for i in range(len(text)) if text[i] != ' ']

    # Remove empty tokens
    text = [text[i] for i in range(len(text)) if text[i] != '']

    # Remove repetition in tokens (!!! => !)
    text = [text[i] for i in range(len(text)) if text[i] != text[i-1]]

    #  Handle the ALL CAPS Tweets 
    ### if ratio of caps in the word > 75% add allcaps tag <allcaps>
    caps_r = np.mean([text[i].isupper() for i in range(len(text))])
    if caps_r > 0.6 : 
        text.append('<allcaps>')

    # Lower Case : 
    text = [text[i].lower() for i in range(len(text))]
    
    return " ".join(str(x) for x in text)

# %%
train_data['subtask_a'].replace({'NOT':0, 'OFF': 1}, inplace= True)

# %%
train_data["preprocessed_tweet"] = train_data["tweet"].apply(clean_tweet)

# %%
train_data.head()
# Out:
#       id                                              tweet  subtask_a  \
# 0  86426  @USER She should ask a few native Americans wh...          1
# 1  90194  @USER @USER Go home you’re drunk!!! @USER #MAG...          1
# 2  16820  Amazon is investigating Chinese employees who ...          0
# 3  62688  @USER Someone should'veTaken" this piece of sh...          1
# 4  43605  @USER @USER Obama wanted liberals &amp; illega...          0
#
#   subtask_b subtask_c                                 preprocessed_tweet
# 0       UNT       NaN  <user> she should ask a few native americans w...
# 1       TIN       IND  <user> go home you re drunk ! <user> maga trum...
# 2       NaN       NaN  amazon is investigating chinese employees who ...
# 3       UNT       NaN  <user> someone should ' ve taken this piece of...
# 4       NaN       NaN  <user> obama wanted liberals and amp illegals ...

# %% [markdown]
# ## Word Cloud

# %%
offensive = train_data.loc[train_data['subtask_a'] == 1].values
len(offensive)
offensive[0][1]

stop_words = set(stopwords.words('english'))
word_tokens = [word_tokenize(question[5]) for question in offensive]

#freq_dist = FreqDist([word for question in insincere_questions for word in question[1].split()])
all_words = [word for question in word_tokens for word in question]
len(all_words)
without_stopwords = [w for w in all_words if not w in stop_words]
words_len = [w for w in without_stopwords if not len(w)<5]
freq_dist = FreqDist([word for word in words_len])

plt.figure(figsize=(12,6))
plt.title(f'Frequency Distribution (Insincere Questions, Top 50 words)')
freq_dist.plot(50, marker='|', markersize=20)
plt.show()

from wordcloud import WordCloud

wordcloud = WordCloud(background_color='White').generate_from_frequencies(freq_dist)
plt.figure(figsize=(12,6))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Feature Extraction

# %%
X = train_data["preprocessed_tweet"].values
y = train_data["subtask_a"].values

# %%
from sklearn.model_selection import train_test_split
train_X, test_X, train_y, test_y = train_test_split(X, y, stratify=y, test_size=0.25)
#train_X, val_X, train_y, val_y = train_test_split(train_X, train_y, stratify=train_y, test_size=0.1)

# %%
print("Train shape : ",train_X.shape)
#print("Validation shape : ",val_X.shape)
print("Test shape : ",test_X.shape)
# Out:
# Train shape :  (9930,)
# Test shape :  (3310,)

# %%
unique, counts = np.unique(train_y, return_counts=True)
print(np.asarray((unique, counts)).T)

# unique, counts = np.unique(val_y, return_counts=True)
# print(np.asarray((unique, counts)).T)

unique, counts = np.unique(test_y, return_counts=True)
print(np.asarray((unique, counts)).T)
# Out:
# [[   0 6630]
#  [   1 3300]]
# [[   0 2210]
#  [   1 1100]]

# %%
testdf = pd.DataFrame()
testdf['tweet'] = test_X

testdf['subtask_a'] = test_y
testdf.shape
# Out:
# (3310, 2)

# %% [markdown]
# ### Using TFIDF

# %%
def tfidf_vectorizer(X, train_X, test_X):
    
    tfidf_vectorizer = TfidfVectorizer()
    tfidf_vectorizer.fit(X)

    train_text_features_tf = tfidf_vectorizer.transform(train_X)
    test_text_features_tf = tfidf_vectorizer.transform(test_X)
    
    return train_text_features_tf, test_text_features_tf

# %% [markdown]
# ### Using Count Vectorizer

# %%
def count_vectorizer(X, train_X, test_X):
    
    count_vectorizer = CountVectorizer()
    count_vectorizer.fit(X)

    train_text_features_cv = count_vectorizer.transform(train_X)
    test_text_features_cv = count_vectorizer.transform(test_X)
    
    return train_text_features_cv, test_text_features_cv

# %% [markdown]
# ## Undersampling

# %%
def undersampleData(train_text_features_tf, train_y):
    rus = RandomUnderSampler(random_state=0)
    X_resampled, y_resampled = rus.fit_resample(train_text_features_tf, train_y)
    return X_resampled, y_resampled

# %% [markdown]
# ## Oversampling

# %%
def oversampleData(train_text_features_tf, train_y):
    from imblearn.over_sampling import SMOTE
    smote = SMOTE('minority')
    x_oversampled, y_oversampled = smote.fit_sample(train_text_features_tf, train_y)
    return x_oversampled, y_oversampled

# %% [markdown]
# ## Function for Confusion Matrix

# %%
def getConfusionMatrix(y_test, y_pred):
  # Confusion matrix
  mat = confusion_matrix(y_test, y_pred)
  cm = pd.DataFrame(mat)
  TP = cm.iloc[1,1] # True Positive
  TN = cm.iloc[0,0] # True Negative
  FP = cm.iloc[0,1] # False Positive
  FN = cm.iloc[1,0] # False Negative

  print('Sensitivity: {:.2%}'.format(TP/(FN+TP)))
  print('Specificity: {:.2%}'.format(TN/(FP+TN)))
  
  sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=True)
  plt.title('A confusion matrix showing the frequency of misclassifications by our classifier')
  plt.xlabel('true label')
  plt.ylabel('predicted label');
  plt.show()

# %% [markdown]
# ## Model

# %%
def model(model, X, train_X, train_y, test_X, test_y, tfidf = True, cv = False, undersampled = False, oversample = False):
    
    if tfidf:
        print('Feature Extraction using TFIFD')
        train_text_features, test_text_features = tfidf_vectorizer(X, train_X, test_X)
    
    if cv:
        print('Feature Extraction using CV')
        train_text_features, test_text_features = count_vectorizer(X, train_X, test_X)

    if undersampled:
        print('Undersampling the dataset')
        train_text_features, train_y = undersampleData(train_text_features, train_y)

    if oversample:
        print('Oversampling the dataset')
        train_text_features, train_y = oversampleData(train_text_features, train_y)
        
    model.fit(train_text_features, train_y)

    # predict the labels on validation dataset
    predictions = model.predict(test_text_features)

    # Use accuracy_score function to get the accuracy
    print("Accuracy Score -> ",accuracy_score(predictions, test_y)*100)

    print('F1Score', f1_score(predictions, test_y, average="macro"))
    print('Precision', precision_score(predictions, test_y, average="macro"))
    print('Recall', recall_score(predictions, test_y, average="macro"))

    getConfusionMatrix(test_y, predictions)

# %% [markdown]
# ## Naive Bayes (Unsampling, TFIDF)

# %%
model(naive_bayes.MultinomialNB(), X, train_X, train_y,
      test_X, test_y, tfidf = True, cv = False, undersampled = True, oversample = False)
# Out:
# Feature Extraction using TFIFD
# Undersampling the dataset
# Accuracy Score ->  68.30815709969788
# F1Score 0.6741165564602059
# Precision 0.70696421225833
# Recall 0.6836918658672964
# Sensitivity: 77.82%
# Specificity: 63.57%

# %% [markdown]
# ## Naive Bayes (Unsampling, CV)

# %%
model(naive_bayes.MultinomialNB(), X, train_X, train_y,
      test_X, test_y, tfidf = False, cv = True, undersampled = True, oversample = False)
# Out:
# Feature Extraction using CV
# Undersampling the dataset
# Accuracy Score ->  66.70694864048339
# F1Score 0.6591673173187578
# Precision 0.6940600575894693
# Recall 0.6724001835972788
# Sensitivity: 77.45%
# Specificity: 61.36%

# %% [markdown]
# ## Naive Bayes

# %%
model(naive_bayes.MultinomialNB(), X, train_X, train_y,
      test_X, test_y, tfidf = False, cv = True, undersampled = False, oversample = False)
# Out:
# Feature Extraction using CV
# Accuracy Score ->  74.74320241691844
# F1Score 0.6939200349001686
# Precision 0.6841526120937886
# Recall 0.7181881718543472
# Sensitivity: 49.55%
# Specificity: 87.29%

# %%
model(naive_bayes.MultinomialNB(), X, train_X, train_y,
      test_X, test_y, tfidf = True, cv = False, undersampled = False, oversample = False)
# Out:
# Feature Extraction using TFIFD
# Accuracy Score ->  69.7583081570997
# F1Score 0.5017934809167766
# Precision 0.549109419991773
# Recall 0.7785301837270342
# Sensitivity: 10.64%
# Specificity: 99.19%

# %% [markdown]
# ### Naive Bayes (Oversampling, CV)

# %%
model(naive_bayes.MultinomialNB(), X, train_X, train_y,
      test_X, test_y, tfidf = True, cv = False, undersampled = False, oversample = True)
# Out:
# Feature Extraction using TFIFD
# Oversampling the dataset
# Accuracy Score ->  68.8821752265861
# F1Score 0.6746851145038169
# Precision 0.6973364870423695
# Recall 0.6763176271684799
# Sensitivity: 72.27%
# Specificity: 67.19%

# %% [markdown]
# ### Naive Bayes (Oversampling, TFIDF)

# %%
model(naive_bayes.MultinomialNB(), X, train_X, train_y,
      test_X, test_y, tfidf = True, cv = False, undersampled = False, oversample = True)
# Out:
# Feature Extraction using TFIFD
# Oversampling the dataset
# Accuracy Score ->  68.94259818731118
# F1Score 0.6750589494488184
# Precision 0.6973323735088441
# Recall 0.676421329653744
# Sensitivity: 72.09%
# Specificity: 67.38%

# %% [markdown]
# ## SVM (Undersampling, TFIDF)

# %%
model(svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto'), X, train_X, train_y,
      test_X, test_y, tfidf = True, cv = False, undersampled = True, oversample = False)
# Out:
# Feature Extraction using TFIFD
# Undersampling the dataset
# Accuracy Score ->  72.68882175226587
# F1Score 0.7041304506032406
# Precision 0.7141999177293294
# Recall 0.6997195518967068
# Sensitivity: 67.64%
# Specificity: 75.20%

# %% [markdown]
# ## SVM (Undersampling, CV)

# %%
model(svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto'), X, train_X, train_y,
      test_X, test_y, tfidf = False, cv = True, undersampled = True, oversample = False)
# Out:
# Feature Extraction using CV
# Undersampling the dataset
# Accuracy Score ->  70.57401812688822
# F1Score 0.6836863083071958
# Precision 0.6953948992184287
# Recall 0.6801127987186721
# Sensitivity: 66.45%
# Specificity: 72.62%

# %% [markdown]
# ## SVM

# %%
model(svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto'), X, train_X, train_y,
      test_X, test_y, tfidf = False, cv = True, undersampled = False, oversample = False)
# Out:
# Feature Extraction using CV
# Accuracy Score ->  74.32024169184291
# F1Score 0.7008055651972693
# Precision 0.6951398601398602
# Recall 0.7097615611281496
# Sensitivity: 55.18%
# Specificity: 83.85%

# %%
model(svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto'), X, train_X, train_y,
      test_X, test_y, tfidf = True, cv = False, undersampled = False, oversample = False)
# Out:
# Feature Extraction using TFIFD
# Accuracy Score ->  77.49244712990937
# F1Score 0.7086150200540975
# Precision 0.6928691896338955
# Recall 0.7773612217819053
# Sensitivity: 44.82%
# Specificity: 93.76%

# %%
model(svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto'), X, train_X, train_y,
      test_X, test_y, tfidf = True, cv = False, undersampled = False, oversample = True)
# Out:
# Feature Extraction using TFIFD
# Oversampling the dataset
# Accuracy Score ->  75.25679758308156
# F1Score 0.718533294418541
# Precision 0.7165364047716989
# Recall 0.7208230609079838
# Sensitivity: 60.91%
# Specificity: 82.40%

# %%
model(svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto'), X, train_X, train_y,
      test_X, test_y, tfidf = False, cv = True, undersampled = False, oversample = True)
# Out:
# Feature Extraction using CV
# Oversampling the dataset
# Accuracy Score ->  64.16918429003022
# F1Score 0.6231611435698006
# Precision 0.6392122583299054
# Recall 0.6250192095705035
# Sensitivity: 63.18%
# Specificity: 64.66%

# %% [markdown]
# ### Random Forest

# %%
#Random Forest Classifier 
from sklearn.ensemble import RandomForestClassifier

model(RandomForestClassifier(n_estimators=100, max_depth=20,random_state=0), X, train_X, train_y,
      test_X, test_y, tfidf = False, cv = True, undersampled = False, oversample = True)
# Out:
# Feature Extraction using CV
# Oversampling the dataset
# Accuracy Score ->  58.549848942598196
# F1Score 0.5414394051996562
# Precision 0.542566844919786
# Recall 0.5411094302204368
# Sensitivity: 41.45%
# Specificity: 67.06%

# %%
#Random Forest Classifier 
from sklearn.ensemble import RandomForestClassifier

model(RandomForestClassifier(n_estimators=100, max_depth=20,random_state=0), X, train_X, train_y,
      test_X, test_y, tfidf = False, cv = True, undersampled = True, oversample = False)
# Out:
# Feature Extraction using CV
# Undersampling the dataset
# Accuracy Score ->  72.59818731117825
# F1Score 0.6927210852534023
# Precision 0.6936589880707528
# Recall 0.6918541698843744
# Sensitivity: 59.73%
# Specificity: 79.00%

# %%
#Random Forest Classifier 
from sklearn.ensemble import RandomForestClassifier

model(RandomForestClassifier(n_estimators=100, max_depth=20,random_state=0), X, train_X, train_y,
      test_X, test_y, tfidf = False, cv = True, undersampled = False, oversample = False)
# Out:
# Feature Extraction using CV
# Accuracy Score ->  67.09969788519638
# F1Score 0.4110627254411773
# Precision 0.505
# Recall 0.8349499848438922
# Sensitivity: 1.00%
# Specificity: 100.00%

# %%
#Random Forest Classifier 
from sklearn.ensemble import RandomForestClassifier

model(RandomForestClassifier(n_estimators=100, max_depth=20,random_state=0), X, train_X, train_y,
      test_X, test_y, tfidf = True, cv = False, undersampled = False, oversample = False)
# Out:
# Feature Extraction using TFIFD
# Accuracy Score ->  67.16012084592144
# F1Score 0.41298757066681935
# Precision 0.5059090909090909
# Recall 0.8351531695480741
# Sensitivity: 1.18%
# Specificity: 100.00%

# %%
#Random Forest Classifier 
from sklearn.ensemble import RandomForestClassifier

model(RandomForestClassifier(n_estimators=100, max_depth=20,random_state=0), X, train_X, train_y,
      test_X, test_y, tfidf = True, cv = False, undersampled = True, oversample = False)
# Out:
# Feature Extraction using TFIFD
# Undersampling the dataset
# Accuracy Score ->  69.06344410876133
# F1Score 0.6684613792485526
# Precision 0.6804298642533937
# Recall 0.6656173633829023
# Sensitivity: 65.00%
# Specificity: 71.09%

# %%
#Random Forest Classifier 
from sklearn.ensemble import RandomForestClassifier

model(RandomForestClassifier(n_estimators=100, max_depth=20,random_state=0), X, train_X, train_y,
      test_X, test_y, tfidf = True, cv = False, undersampled = False, oversample = True)
# Out:
# Feature Extraction using TFIFD
# Oversampling the dataset
# Accuracy Score ->  69.72809667673717
# F1Score 0.6379433437039463
# Precision 0.6326696832579185
# Recall 0.6519314113435086
# Sensitivity: 44.00%
# Specificity: 82.53%

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

model(LogisticRegression(), X, train_X, train_y,
      test_X, test_y, tfidf = False, cv = True, undersampled = False, oversample = False)
# Out:
# Feature Extraction using CV
# /Users/nikhiloswal/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Accuracy Score ->  76.04229607250755
# F1Score 0.7090382131284032
# Precision 0.6979905388728918
# Recall 0.7359238067788851
# Sensitivity: 51.18%
# Specificity: 88.42%

# %%
from sklearn.linear_model import LogisticRegression

model(LogisticRegression(), X, train_X, train_y,
      test_X, test_y, tfidf = True, cv = False, undersampled = False, oversample = False)
# Out:
# Feature Extraction using TFIFD
# Accuracy Score ->  75.89123867069486
# F1Score 0.6741754655006269
# Precision 0.6623858494446729
# Recall 0.7712500755839201
# Sensitivity: 37.45%
# Specificity: 95.02%

# %%
from sklearn.linear_model import LogisticRegression

model(LogisticRegression(), X, train_X, train_y,
      test_X, test_y, tfidf = True, cv = False, undersampled = True, oversample = False)
# Out:
# Feature Extraction using TFIFD
# Undersampling the dataset
# Accuracy Score ->  71.63141993957703
# F1Score 0.6929532742354654
# Precision 0.7028568490333196
# Recall 0.688882135050468
# Sensitivity: 66.27%
# Specificity: 74.30%
# /Users/nikhiloswal/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
from sklearn.linear_model import LogisticRegression

model(LogisticRegression(), X, train_X, train_y,
      test_X, test_y, tfidf = False, cv = True, undersampled = False, oversample = False)
# Out:
# Feature Extraction using CV
# Accuracy Score ->  76.04229607250755
# F1Score 0.7090382131284032
# Precision 0.6979905388728918
# Recall 0.7359238067788851
# Sensitivity: 51.18%
# Specificity: 88.42%

# %%
from sklearn.linear_model import LogisticRegression

model(LogisticRegression(), X, train_X, train_y,
      test_X, test_y, tfidf = False, cv = True, undersampled = True, oversample = False)
# Out:
# Feature Extraction using CV
# Undersampling the dataset
# Accuracy Score ->  72.20543806646525
# F1Score 0.69845396759004
# Precision 0.7078403948992185
# Recall 0.6942273805020711
# Sensitivity: 66.55%
# Specificity: 75.02%
# /Users/nikhiloswal/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
from sklearn.linear_model import LogisticRegression

model(LogisticRegression(), X, train_X, train_y,
      test_X, test_y, tfidf = False, cv = True, undersampled = False, oversample = True)
# Out:
# Feature Extraction using CV
# Oversampling the dataset
# Accuracy Score ->  66.43504531722054
# F1Score 0.6413045460872269
# Precision 0.6527560674619498
# Recall 0.6396909157457072
# Sensitivity: 61.82%
# Specificity: 68.73%

# %%
from sklearn.linear_model import LogisticRegression

model(LogisticRegression(), X, train_X, train_y,
      test_X, test_y, tfidf = True, cv = False, undersampled = False, oversample = True)
# Out:
# Feature Extraction using TFIFD
# Oversampling the dataset
# Accuracy Score ->  74.65256797583082
# F1Score 0.7086821140915767
# Precision 0.7049341834635953
# Recall 0.7136359601557645
# Sensitivity: 58.09%
# Specificity: 82.90%
